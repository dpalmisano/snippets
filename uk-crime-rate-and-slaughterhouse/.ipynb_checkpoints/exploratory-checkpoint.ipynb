# %%
import numpy as np

from src.utils import crime_counts_by_msoa
from src.utils import get_crimes_and_residents
from src.utils import load_residents
from src.utils import plants

# %% [markdown]
# ## crimes / residents per year ratio on a msoa level

# %%
residents = load_residents()
crimes = crime_counts_by_msoa('data/crime/*')
crimes_and_residents = get_crimes_and_residents(crimes, residents)

# %% [markdown]
# ### Basic stats

# %%
crimes_and_residents['ratio'].describe()
# Out:
# count    7201.000000
# mean        0.033363
# std         0.029660
# min         0.001973
# 25%         0.016644
# 50%         0.025865
# 75%         0.040685
# max         0.511962
# Name: ratio, dtype: float64

# %% [markdown]
# ### Histogram

# %%
max_x = 0.2
crimes_and_residents['ratio'].plot.hist(figsize=(15,7), alpha=0.6, by='ratio', bins=np.arange(0, max_x, 0.01), edgecolor="k").set_xlim((0,max_x))
# Out:
# (0, 0.2)

# %% [markdown]
# ### Density

# %%
crimes_and_residents['ratio'].plot.density(figsize=(15,7)).set_xlim((0,max_x))
# Out:
# (0, 0.2)

# %% [markdown]
# ### Meat manifacturing plans

# %%
import pandas as pd
plants = pd.read_csv('output/plants.csv')

# %%
plants
# Out:
#       Unnamed: 0 Approval Number  \
# 0              0          AR 001
# 1              1          AR 003
# 2              2          AR 008
# 3              3          AR 009
# 4              4          AR 010
# 5              5          AE 001
# 6              8         AE 006
# 7              9          AE 021
# 8             10         AE 023
# 9             11         AE 027
# 10            12          AE 029
# 11            13          AE 030
# 12            14          AE 032
# 13            16          AE 102
# 14            17          AE 112
# 15            19          AE 203
# 16            20          AE 204
# 17            22          AE 214
# 18            23          AV 002
# 19            24          AV 014
# 20            25          AV 017
# 21            26          AV 018
# 22            28          AV 020
# 23            29          AV 021
# 24            30          AV 022
# 25            31          AV 024
# 26            32          AV 025
# 27            33          AV 026
# 28            34          AN 002
# 29            35          AN 007
# ...          ...             ...
# 4916        1921            9143
# 4917        1922            9148
# 4918        1923            9152
# 4919        1924            9165
# 4920        1925            9168
# 4921        1926            9170
# 4922        1927            9198
# 4923        1928            9203
# 4924        1929            9204
# 4925        1930            9205
# 4926        1977            9520
# 4927        1986          ZS 005
# 4928        2462            7008
# 4929        2466            7016
# 4930        2467            7020
# 4931        2468            7022
# 4932        2470            7024
# 4933        2472            7028
# 4934        2473            7030
# 4935        2476            7040
# 4936        2477            7044
# 4937        2481            7050
# 4938        2482            7051
# 4939        2483            7053
# 4940        2484            7055
# 4941        2485            7058
# 4942        2486            7060
# 4943        2487            7061
# 4944        2491            7085
# 4945        2497            7115
#
#                                        Trading Name   Postcode outcode incode  \
# 0                                       Monteum Ltd   BN43 6RN    BN43    6RN
# 1                               Southover Foods Ltd   BN42 4EN    BN42    4EN
# 2                                       Higgidy Ltd   BN43 6PD    BN43    6PD
# 3                                       Little Tums   BN43 6NZ    BN43    6NZ
# 4                                   Malpass Markets   BN43 6RN    BN43    6RN
# 5                               Booker Cash & Carry   CA14 2TQ    CA14    2TQ
# 6                                 Macknight Limited   CA15 8NF    CA15    8NF
# 7                              Solway Browm Shrimps    CA7 4AE     CA7    4AE
# 8                Maryport and Solway Fishing Co-op.   CA15 8AB    CA15    8AB
# 9                             Rays  Shrimps Limited    CA7 4AE     CA7    4AE
# 10                        Macknight Limited Plant 2   CA15 8NF    CA15    8NF
# 11                       Taste of the Lakes Limited   CA15 8NF    CA15    8NF
# 12                         Harbourside Products Ltd   CA15 8NT    CA15    8NT
# 13                               Thornby Moor Dairy    CA5 6QB     CA5    6QB
# 14                         Classic Desserts Limited  CA12 4TR     CA12    4TR
# 15                           Caterite Food Services   CA13 9XP    CA13    9XP
# 16                          Haighs (Workington) Ltd   CA14 3AG    CA14    3AG
# 17                               Shaw Meats Limited    CA7 3DP     CA7    3DP
# 18                         Loscoe Chilled Foods Ltd   DE75 7JT    DE75    7JT
# 19                              The Cow House Dairy   DE56 2LD    DE56    2LD
# 20                               The Duffield Dairy   DE56 4FQ    DE56    4FQ
# 21                             Hunt's Quality Meats   DE55 4BR    DE55    4BR
# 22                                   Oak Apple Farm    DE6 4PQ     DE6    4PQ
# 23                                 Castle Farm Eggs   DE75 7HB    DE75    7HB
# 24                        Featherfield Poultry Farm    DE4 5GX     DE4    5GX
# 25             Bidvest Foodservice Nottingham Depot   NG16 4HY    NG16    4HY
# 26                                J C Coombes & Son   DE56 2JU    DE56    2JU
# 27                        Southcliffe Foods Limited   DE55 7RQ    DE55    7RQ
# 28                             Turner's Dairies LLP   BN13 3XL    BN13    3XL
# 29                         The Fab Food Company Ltd   PO22 9RU    PO22    9RU
# ...                                             ...        ...     ...    ...
# 4916                               Currie Farm Eggs   BT40 2PR    BT40    2PR
# 4917                            Farmview Fresh Eggs   BT80 9NS    BT80    9NS
# 4918                                    Ivor Girvin   BT27 6TU    BT27    6TU
# 4919                            Mountain View Farm    BT45 6NL    BT45    6NL
# 4920                                 Hillclose Farm   BT24 8UL    BT24    8UL
# 4921                                S J Biggerstaff   BT32 4HJ    BT32    4HJ
# 4922                                 Fruitvale Farm   BT28 2LF    BT28    2LF
# 4923                           Ballyeamon Eggs Ltd.   BT44 0SN    BT44    0SN
# 4924                                 Marianne Buick   BT42 3NL    BT42    3NL
# 4925                           Armstrong Meats Ltd     BT6 9SR     BT6    9SR
# 4926                                 GB Poultry Ltd   BT30 9DG    BT30    9DG
# 4927                                      JTM Meats   BT51 3PE    BT51    3PE
# 4918                    NaN       Ballymacbrennan 2
# 4919                    NaN               Lecumpher
# 4920                    NaN       Ballymacbrennan 2
# 4921                    NaN                  Quilly
# 4922                    NaN               Glenavy 1
# 4923                    NaN       Glenaan & Glendun
# 4924                    NaN                 Kells 2
# 4925                    NaN            Moneyreagh 1
# 4926                    NaN              Crossgar 1
# 4927                    NaN               Macosquin
# 4928    Carmarthenshire 008    Carmarthenshire 008B
# 4929         Ceredigion 008         Ceredigion 008C
# 4930   Isle of Anglesey 006   Isle of Anglesey 006B
# 4931         Ceredigion 001         Ceredigion 001F
# 4932       Denbighshire 012       Denbighshire 012B
# 4933    Carmarthenshire 015    Carmarthenshire 015C
# 4934            Gwynedd 011            Gwynedd 011D
# 4935            Cardiff 005            Cardiff 005B
# 4936  Rhondda Cynon Taf 022  Rhondda Cynon Taf 022D
# 4937      Pembrokeshire 010      Pembrokeshire 010C
# 4938           Bridgend 015           Bridgend 015D
# 4939         Ceredigion 010         Ceredigion 010B
# 4940         Ceredigion 010         Ceredigion 010B
# 4941            Gwynedd 011            Gwynedd 011D
# 4942    Carmarthenshire 004    Carmarthenshire 004D
# 4943         Ceredigion 010         Ceredigion 010B
# 4944    Carmarthenshire 026    Carmarthenshire 026G
# 4945            Wrexham 015            Wrexham 015C
#
# [4946 rows x 8 columns]

# %%
plants['msoa'].unique()
# Out:
# array(['Adur 004', 'Allerdale 009', 'Allerdale 004', ..., 'Cardiff 005',
#        'Rhondda Cynon Taf 022', 'Bridgend 015'], dtype=object)

# %%
crimes_and_residents_with_plants = crimes_and_residents.loc[crimes_and_residents['MSOA'].isin(plants['msoa'].unique())]

# %%
crimes_and_residents_with_plants['ratio'].describe()
# Out:
# count    2219.000000
# mean        0.033042
# std         0.032679
# min         0.002816
# 25%         0.015090
# 50%         0.024205
# 75%         0.040178
# max         0.511962
# Name: ratio, dtype: float64

# %%
crimes_and_residents_with_plants['ratio'].plot.hist(figsize=(15,7), alpha=0.6, by='ratio', bins=np.arange(0, max_x, 0.01), edgecolor="k").set_xlim((0,max_x))
# Out:
# (0, 0.2)

# %% [markdown]
# ### Density comparison

# %%
import matplotlib.pyplot as plt

# %%
fig, ax = plt.subplots(1,1)
crimes_and_residents['ratio'].plot.density(figsize=(15,7), color='green', label="total population").set_xlim((0,max_x))
crimes_and_residents_with_plants['ratio'].plot.density(figsize=(15,7), color='blue', label="with man plant").set_xlim((0,max_x))
legend = ax.legend(loc='upper center', shadow=True)
fig.show()
# Out:
# /opt/anaconda/envs/Python3/lib/python3.6/site-packages/matplotlib/figure.py:403: UserWarning: matplotlib is currently using a non-GUI backend, so cannot show the figure
#   "matplotlib is currently using a non-GUI backend, "
